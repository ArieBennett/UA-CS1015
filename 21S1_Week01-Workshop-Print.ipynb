# %% [markdown]
# # Workshop 01
#
# Welcome to your first workshop for Introduction to Programming for IT Specialists! These workshops will be your primary contact with lecturing staff and there will be many different types of activities conducted here. That's a big hint that you must attend the workshops, as there are many opportunities here for learning, development of your skills, and marks.
#
# Today, we're going to get to know each other a little, get logged in to Canvas, watch a couple of videos, write our first Python programs, and have some fun!

# %% [markdown]
# ## 1. Introduction & Assessment (15 minutes)
#
# We have to go through some administrative details for this course but we'll try to keep it short. All lecture notes are always available on-line.

# %% [markdown]
# ## 2. Say Hello! (10 minutes)
# Your first task is to get to know three people around you that you don't already know!
#
# Start with these questions and then add some of your own:
# - What's your name (easy questions first!)
# - What's the most interesting thing you've ever seen a program or computer do?
# - What would you like to be able to do by the end of this course?

# %% [markdown]
# ## 3. Canvas (10 minutes)
# You will be using a combination of Canvas and Jupyter Notebooks(these pages!) while you're working with us. Canvas can be accessed on and off campus. While you're in this lab, you will need to log in to use the computer systems, let's get started!
#
# Use your University ID and password to log in. Tip: type your password carefully as too many failed attempts will lock your account.
#
# Go to https://myuni.adelaide.edu.au and enter your University ID and password to log in.
# Navigate to the 4010_COMP_SCI_X_0024 course page.
#
# To the left you will see a 'Modules' menu - in the first module you will see important pages for contact information, the assessment schedule and the topic schedule.
#
# Click on the 'Discussion' menu. We will use the Canvas Discussion tool in this course for questions and discussions. Find the 'Hello' discussion thread and introduce yourself! Let everyone know your name, interest, and perhaps your favourite movie!
#
# Remember: anything you post in any of our spaces should be at a professional standard; well-written, clear, polite and avoiding hostile, discriminatory, or offensive language.
#
# Next make sure you receive notifications for important course updates. At a bare minimum you need to make sure you receive email notifications for course announcements as this will be the main method of communication between staff and students. If you find yourself having trouble, please stick your hand up!

# %% [markdown]
# ## 4. First Video Lectures (10 minutes)
# Now we are going to take a look at the first few videos from our on-line content. Normally you will view these videos in preparation for your weekly workshop sessions but today is a bit of a special case.
#
# Today we'll watch the first two Introduction to Python videos.

# %% [markdown]
# # Introduction to Python (50 min)

# %% [markdown]
# You should have already been introduced to the concept of higher order languages compared to compiled languages in your lecture notes. Languages which are strictly are prepared before being run through a compiler to convert it into machine code for the computer to understand. Python isn't one of these languages. Python is compiled behind the scenes, but, it does this without you having to worry about it! This means that we won't have to explicitly compile our code.
#
# <img src="https://imgs.xkcd.com/comics/compiling.png">
# <center>Source: XKCD-Compile https://xkcd.com/303/</center>
#
# While we haven't learnt many things about the language yet we can write a program introducing you to the concepts.
#
# By the end of this workshop you'll be able to:
# * print characters using the <code>print()</code> function.
# * use unicode to draw a chess board.
# * use special characters such as the newline and tab
# * multiple methods of input using the <code>print</code>

# %% [markdown]
# ## Demo 0: Jupyter Notebook

# %% [markdown]
# You will use the Jupyter notebook in this semester. It is an open-source web application that allows you to create and share documents that contain live code, equations, visualizations and narrative text.
#
# If you are using the machine in the lab, you can start the Jupyter notebook server by opening up your terminal and type
#
# `jupyter notebook`
#
# or you can also launch the `anaconda navigator` via the start menu and click either the `jupyter-lab` or `jupyter-notebook`.
#
# <div>
# <img src="attachment:2021-03-01_11-44-43.jpg" width="600"/>
# </div>
#
# Jupyter notebook consists of a series of `cells`. Each cell can be text or executable live code. You can identify the type of the cell by looking at the menu bar(as shown in figure below) or by the color of the cell.

# %% [markdown]
# <div>
# <img src="attachment:41d78393-3f7d-4e72-be9e-541081977045.jpg" width="600"/>
# </div>

# %% [markdown]
# ## Demo 1 : Hello World
#
# Many people start programming in a new language by learning to output characters to the screen. One way to to that is to write the popular "hello world" program.
#
# Let's do that now.
#
# In Python we can do this by using the <code>print</code> command.
#
# Run the example in the cell below and see what happens.<br>
#
# **Note**: select the cell with your arrow key, edit the cell by press "enter". To run and exit the cell editing, press "shift + enter".

# %%
print("This is how we print something to the page using python.")
# Out:
# This is how we print something to the page using python.
# test test

# %% [markdown]
# You've just written your first line of Python code! Normally to run Python we would have to launch it from the command line interface (CLI) using the command <code>Python3</code>. However, luckily for us, Python is built into Jupyter Notebooks. This means we can run it directly from cells!
#
# You can experiment with this command. Try changing anything between the <code>"</code> and <code>"</code> characters. What happens? Modify the above line to write your name and student number.
#
# Let's break down what's going on here.
#
# The above code is called a **function**. This takes something as an input, does soemthing with it and then might return a value according to what the function is programmed to do. The function you've just used here is called <code>print</code>. It's important to note that Python is case-sensitive. The function is <code>print()</code> and not PRINT().
#
# To input things to the function we "pass" values called "**arguments**". This is done through the use of the ("parentheses").
#
# By changing the value of what was inside the parentheses you changed what was parsed to the function as an input and modified what the function had to do. In this case the function will output what ever is inside the parentheses to the screen. We need use quotation marks to tell Python that we are parsing text directly to the function rather than a variable (we'll look at this next week).
#
# When you are ready write code in the cell below to print to the notebook the words "Hello world!" and check it against the expected output below.

# %%
#INSERT YOUR CODE HERE

# %% [markdown]
# You should see **Hello World!** above

# %% [markdown]
# Using the <code>print()</code> function we can write anything which Python3 supports. Luckily, Python3 supports "Unicode" or an international standard which allows our keyboards to type in any international and scientific characters.
#
# The difficult point is on how to enter them given each operating system may have differnt keystrokes. If we head to https://unicode.org/charts/ we will find all the charcter charts supported by unicode. Such characters even include game playing peices such as those found in chess. https://unicode.org/charts/PDF/U2600.pdf
#
# Use the unicode above, we can print out a chessboard! Try run the code below (shift + enter)

# %%
print("   [A][B][C][D][E][F][G][H]")
print("[8][ ][ ][ ][ ][ ][ ][ ][ ]")
print("[7][ ][ ][ ][ ][ ][ ][ ][ ]")
print("[6][ ][ ][ ][ ][ ][ ][ ][ ]")
print("[5][ ][ ][ ][ ][ ][ ][ ][ ]")
print("[4][ ][ ][ ][ ][ ][ ][ ][ ]")
print("[3][ ][ ][ ][ ][ ][ ][ ][ ]")
print("[2][\u2659][\u2659][\u2659][\u2659][\u2659][\u2659][\u2659][\u2659]")
print("[1][\u2656][\u2658][\u2657][\u2655][\u2654][\u2657][\u2658][\u2656]")
print("   [A][B][C][D][E][F][G][H]")
# Out:
#    [A][B][C][D][E][F][G][H]
# [8][ ][ ][ ][ ][ ][ ][ ][ ]
# [7][ ][ ][ ][ ][ ][ ][ ][ ]
# [6][ ][ ][ ][ ][ ][ ][ ][ ]
# [5][ ][ ][ ][ ][ ][ ][ ][ ]
# [4][ ][ ][ ][ ][ ][ ][ ][ ]
# [3][ ][ ][ ][ ][ ][ ][ ][ ]
# [2][♙][♙][♙][♙][♙][♙][♙][♙]
# [1][♖][♘][♗][♕][♔][♗][♘][♖]
#    [A][B][C][D][E][F][G][H]

# %% [markdown]
# ## Coding Activity 1: Complete the Chess Board

# %% [markdown]
# You'll note that only white has set up their pieces. We need to draw black's. The unicodes you'll need are below:
#
# \u265F - Black Pawn<br>
# \u265E - Black Knight<br>
# \u265D - Black Bishop<br>
# \u265C - Black Rook<br>
# \u265B - Black Queen<br>
# \u265A - Black King<br>
#
# Finish the board. Don't forget that the board is set up as a mirror and the king's go opposite each other.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# update the board here

print("   [A][B][C][D][E][F][G][H]")
print("[8][ ][ ][ ][ ][ ][ ][ ][ ]")
print("[7][ ][ ][ ][ ][ ][ ][ ][ ]")
print("[6][ ][ ][ ][ ][ ][ ][ ][ ]")
print("[5][ ][ ][ ][ ][ ][ ][ ][ ]")
print("[4][ ][ ][ ][ ][ ][ ][ ][ ]")
print("[3][ ][ ][ ][ ][ ][ ][ ][ ]")
print("[2][\u2659][\u2659][\u2659][\u2659][\u2659][\u2659][\u2659][\u2659]")
print("[1][\u2656][\u2658][\u2657][\u2655][\u2654][\u2657][\u2658][\u2656]")
print("   [A][B][C][D][E][F][G][H]")
# Out:
#    [A][B][C][D][E][F][G][H]
# [8][ ][ ][ ][ ][ ][ ][ ][ ]
# [7][♟][♟][♟][♟][♟][♟][♟][♟]
# [6][ ][ ][ ][ ][ ][ ][ ][ ]
# [5][ ][ ][ ][ ][ ][ ][ ][ ]
# [4][ ][ ][ ][ ][ ][ ][ ][ ]
# [3][ ][ ][ ][ ][ ][ ][ ][ ]
# [2][♙][♙][♙][♙][♙][♙][♙][♙]
# [1][♖][♘][♗][♕][♔][♗][♘][♖]
#    [A][B][C][D][E][F][G][H]

# %% [markdown]
# As an extension, why don't you re-draw the board as a checkers board! Use the unicode pdf above to find a suitable character to represent the red and black checks.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# input your code here to create a new board

# %% [markdown]
# ## Demo 2 - Special Characters

# %% [markdown]
# Rather than using ten <code>print()</code> functions we could have just used one to draw the entire board. To do this we would have had to include the newline character. This is the character that is inserted when we press the return key on our system.
#
# But, we we press the enter key when coding we simply go to a newline and the character itself is ignored.
#
# Similarly, what if we wanted to use "quatation marks" inside our text?
#
# This is where we need to use a \backslash in order to "escape" our characters.

# %%
print("This text is on one line.\nThis will appear on a new line.")
# Out:
# This text is on one line.
# This will appear on a new line.

# %% [markdown]
# There are a series of special characters that we can use in the <code>print()</code> function:
# * \' ----> '
# * \" ----> "
# * \n ----> newline
# * \t ----> tab

# %%
print('\t\tThe Old Sea-dog at the Admiral Benbow\n\n\nSQUIRE TRELAWNEY, Dr. Livesey, and the rest of these\n gentlemen having asked me to write down the whole\nparticulars about Treasure Island, from the beginning\nto the end, keeping nothing back but the bearings of the\nisland, and that only because there is still treasure not\nyet lifted, I take up my pen in the year of grace 17__\nand go back to the time when my father kept the Admiral\nBenbow inn and the brown old seaman with the sabre cut\nfirst took up his lodging under our roof.')
# Out:
# 		The Old Sea-dog at the Admiral Benbow
#
#
# SQUIRE TRELAWNEY, Dr. Livesey, and the rest of these
#  gentlemen having asked me to write down the whole
# particulars about Treasure Island, from the beginning
# to the end, keeping nothing back but the bearings of the
# island, and that only because there is still treasure not
# yet lifted, I take up my pen in the year of grace 17__
# and go back to the time when my father kept the Admiral
# Benbow inn and the brown old seaman with the sabre cut
# first took up his lodging under our roof.

# %% [markdown]
# ## Coding Activity 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Above is a famous poem by Langston Hughes. Plese use **one** single print function and the newline character to print out the poem in the similar format as above.

# %%
# input your code here
# Out:
# DREAMS
#
# Hold fast to dreams
#
# Hold fast to dreams

# %% [markdown]
# # WAIT...WHERE IS THE PYTHON FILE?

# %% [markdown]
# When you hit `ctrl+s` or `File/Save Notebook`, all your modification will be saved in the Jupyter notebook. In this case, a file in your download folder which is called `21S1_Week01-Workshop-Print.ipynb`.
#
# You will be submitting Jupyter notebook in your prac assignment, coding assignment, and prac exams throughout the semester!.
#
# <font color='red'>Note, DO NOT submit a html file!</font>

# %% [markdown]
# ## Demo3 - QR Code

# %% [markdown]
# Python is a powerful language and can do way more than text. Below is a short example showing we can create a qrcode with two lines!
#
# The code below uses a **library** called "qrcode". A Python library is a collection of functions (like the print() function you just used) that can help you achieve your desired goals without writing your own codes. For example, the qrcode library provides a series of function that generates and saves the qr code images. Know when and how to use public Python library is a key to become a good Python programmer!
#
# We can download the qrcode library by the following command
#
# `conda install -c conda-forge qrcode`
#
# Then we can use the functions inside the libarary using the `import` keyword as below

# %%
import qrcode
img = qrcode.make('http://ht-timchen.com') # img is a variable, we will talk about it in Week 3
img.save('home.png')

# %% [markdown]
# ## Easter Egg

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
